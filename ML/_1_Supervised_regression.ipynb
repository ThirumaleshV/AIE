# %% [markdown]
# # 1.simple linear regression

# %% [markdown]
# ## What is Linear Regression?
#
# - **Linear Regression** helps to establish the relationship between the **dependent variable** and **independent variable(s)**.
#
# - **Linear Regression** is a supervised machine learning algorithm used to find the relationship between input and output.
#
# It is mainly used to **predict numerical values**.
#
# ### Example
#
# Suppose we want to predict the **price of a house** using its **area**.
#
# - **Area** → Independent variable (input)
# - **Price** → Dependent variable (output)
#
# The model learns the relationship between area and price and predicts the price of a new house.
#
# ---
#
# ## Simple Linear Regression
#
# When there is **one independent variable**, we use:
#
# $$
# y = mx + b
# $$
#
# Where:
#
# - `y` = Dependent variable / predicted value
# - `x` = Independent variable / input
# - `m` = Slope (or Gradient)
# - `b` = Y-intercept
#
# ### House Price Example
#
# $$
# price = m \times area + b
# $$
#
# Here:
#
# - `price` → Dependent variable
# - `area` → Independent variable
# - `m` → Slope
# - `b` → Y-intercept
#
# ---
#
# ## Slope (m)
#
# **Slope tells us how much `y` changes when `x` increases by 1.**
#
# Example:
#
# $$
# price = 50 \times area + 100
# $$
#
# Here:
#
# ```text
# m = 50

# %%
import pandas as pd

# %%
df = pd.read_csv(r"..\Datasets\home_prices.csv",names=["area","price"],skiprows=1)
df
# Out:
#     area  price
# 0    656   39.0
# 1   1260   83.2
# 2   1057   86.6
# 3   1259   59.0
# 4   1800  140.0
# 5   1325   80.1
# 6   1085  116.0
# 7   1110   45.0
# 8   1700  100.0
# 9    960   89.0
# 10  1800   90.0
# 11   700   49.0

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(df[["area"]],df["price"])
# Out:
# LinearRegression()

# %%
model.predict([[1500]])
# Out:
# C:\Users\thiru\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([95.56913434])

# %%
model.predict([[1500],[1200]])
# Out:
# C:\Users\thiru\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([95.56913434, 80.06460769])

# %%
model.coef_ #slope
# Out:
# array([0.05168176])

# %%
model.intercept_ #y-intercept
# Out:
# np.float64(18.046501102723433)

# %%
model.coef_[0]*1200 + model.intercept_
# Out:
# np.float64(80.0646076905961)

# %% [markdown]
# # Mulitlinear_regression

# %% [markdown]
# ## What is Multiple Linear Regression?
#
# **Multiple Linear Regression** is a supervised machine learning algorithm used to predict one numerical output using **two or more input variables**.
#
# ### Simple Example
#
# Suppose we want to predict the **price of a house**.
#
# The price may depend on:
#
# - Area
# - Number of bedrooms
# - Age of the house
#
# So, we use all these inputs to predict the price.
#
# ## Formula
#
# $$
# y = m_1x_1 + m_2x_2 + m_3x_3 + b
# $$
#
# Where:
#
# - `y` = predicted output
# - `x₁, x₂, x₃` = independent variables (inputs)
# - `m₁, m₂, m₃` = coefficients
# - `b` = intercept
#
# ### House Price Example
#
# $$
# price = m_1(area) + m_2(bedrooms) + m_3(age) + b
# $$
#
# Here:
#
# - `price` → Dependent variable
# - `area` → Independent variable
# - `bedrooms` → Independent variable
# - `age` → Independent variable
#
# ## Simple Linear vs Multiple Linear Regression
#
# **Simple Linear Regression:**
#
# Uses only **one input**.
#
# $$
# price = m(area) + b
# $$
#
# **Multiple Linear Regression:**
#
# Uses **multiple inputs**.
#
# $$
# price = m_1(area) + m_2(bedrooms) + m_3(age) + b
# $$
#
# For example:
#
# **Area + Bedrooms + Age → House Price**

# %%
import pandas as pd

# %%
df=pd.read_csv(r"..\Datasets\home_prices_ml.csv",names=["area","price","Bedrooms"],skiprows=1)

# %%
df
# Out:
#     area  price  Bedrooms
# 0    656   39.0         2
# 1   1260   83.2         2
# 2   1057   86.6         3
# 3   1259   59.0         2
# 4   1800  140.0         3
# 5   1325   80.1         2
# 6   1085  116.0         3
# 7   1110   45.0         2
# 8   1700  100.0         3
# 9    960   89.0         2
# 10  1800   90.0         3
# 11   700   49.0         2

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(df[["area","Bedrooms"]],df["price"])
# Out:
# LinearRegression()

# %%
test=pd.DataFrame([
    {"area":1500,"Bedrooms":3},
    {"area":100,"Bedrooms":3}
])

# %%
model.predict(test)
# Out:
# array([106.82967328,  69.45531207])

# %%
test=pd.DataFrame({
    "area":[1500,100],
    "Bedrooms":[3,3]})
model.predict(test)
# Out:
# array([106.82967328,  69.45531207])

# %%
model.predict([[650,2]])
# Out:
# C:\Users\thiru\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53.09813648])

# %%
model.coef_ #slope
# Out:
# array([2.66959723e-02, 3.10399604e+01])

# %%
model.intercept_ #y-intercept
# Out:
# np.float64(-26.334166207939006)

# %%
#y=m1*area+m2*Bedrooms+b
predicted_price = model.coef_[0]*650 + model.coef_[1]*2 + model.intercept_
predicted_price
# Out:
# np.float64(53.09813648128943)

# %% [markdown]
# # cost function

# %% [markdown]
# ## Linear Regression: Slope, Best Fit Line, Error, MAE and MSE
#
# ## 1. Slope
#
# **Slope** tells us how much `y` changes when `x` changes.
#
# Slope is also called **Gradient**.
#
# $$
# m = \frac{\text{Change in }y}{\text{Change in }x}
# $$
#
# ### Example
#
# Change in `y` = 3
# Change in `x` = 5
#
# $$
# m = \frac{3}{5} = 0.6
# $$
#
# So, the slope is `0.6`.
#
# ---
#
# ## 2. Equation of a Straight Line
#
# The equation of a straight line is:
#
# $$
# y = mx + b
# $$
#
# Where:
#
# - `y` = predicted value
# - `x` = input
# - `m` = slope / gradient
# - `b` = intercept
#
# ### Example
#
# $$
# y = 2x + 3
# $$
#
# If `x = 4`:
#
# $$
# y = 2(4) + 3 = 11
# $$
#
# So, the predicted value is `11`.
#
# ---
#
# ## 3. Best Fit Line
#
# In Linear Regression, we have many data points.
#
# The model tries to find the **best line that fits these data points**.
#
# This line is called the **Best Fit Line**.
#
# The model finds the appropriate values for:
#
# - `m` → slope
# - `b` → intercept
#
# The goal is to make the predicted values as close as possible to the actual values.
#
# ---
#
# ## 4. Error
#
# **Error** is the difference between the actual value and the predicted value.
#
# ### Example
#
# Actual value = `500`
#
# Predicted value = `450`
#
# $$
# Error = Actual - Predicted
# $$
#
# $$
# Error = 500 - 450 = 50
# $$
#
# So, the error is `50`.
#
# ---
#
# ## 5. Loss
#
# **Loss** is a measure of how wrong the model's predictions are.
#
# A smaller loss generally means the predictions are closer to the actual values.
#
# MAE and MSE are two common ways to measure prediction error.
#
# ---
#
# ## 6. Mean Absolute Error (MAE)
#
# **MAE** stands for **Mean Absolute Error**.
#
# It calculates the **average of the absolute errors** between actual and predicted values.
#
# $$
# MAE = \frac{1}{n}\sum_{i=1}^{n}|y_i-\hat{y}_i|
# $$
#
# Where:
#
# - `y` = actual value
# - `ŷ` = predicted value
# - `n` = number of observations
#
# ### Example
#
# Suppose the errors are:
#
#     10, -20, 30
#
# Take the absolute values:
#
#     10, 20, 30
#
# Then:
#
# $$
# MAE = \frac{10+20+30}{3}
# $$
#
# $$
# MAE = 20
# $$
#
# So, the model's prediction is **20 units away from the actual value on average**.
#
# ### Why use absolute values?
#
# Positive and negative errors should not cancel each other.
#
# For example:
#
#     10 + (-10) = 0
#
# This would incorrectly suggest there is no error.
#
# Instead:
#
#     |10| + |-10| = 20
#
# ---
#
# ## 7. Mean Squared Error (MSE)
#
# **MSE** stands for **Mean Squared Error**.
#
# It calculates the **average of the squared errors**.
#
# $$
# MSE = \frac{1}{n}\sum_{i=1}^{n}(y_i-\hat{y}_i)^2
# $$
#
# ### Example
#
# Suppose the errors are:
#
#     10, -20, 30
#
# Square each error:
#
#     10² = 100
#     (-20)² = 400
#     30² = 900
#
# Then:
#
# $$
# MSE = \frac{100+400+900}{3}
# $$
#
# $$
# MSE = 466.67
# $$
#
# So, the MSE is `466.67`.
#
# ---
#
# ## 8. Why Does MSE Square the Errors?
#
# Squaring makes **large errors much more significant**.
#
# For example:
#
#     Error = 2
#     2² = 4
#
#     Error = 10
#     10² = 100
#
# Therefore, MSE strongly penalizes large errors.
#
# ---
#
# ## 9. MAE vs MSE
#
# | MAE | MSE |
# |---|---|
# | Uses absolute errors | Uses squared errors |
# | Easy to understand | Less directly interpretable |
# | Large errors are not heavily punished | Large errors are heavily punished |
# | Treats errors more equally | Gives more importance to large errors |
#
# ---
#
# ## 10. Where Are MAE and MSE Used?
#
# MAE and MSE are mainly used to **evaluate regression models**.
#
# The process is:
#
#     Training Data
#           ↓
#     Train the Model
#           ↓
#     Make Predictions
#           ↓
#     Compare Predictions with Actual Values
#           ↓
#     Calculate MAE / MSE
#           ↓
#     Evaluate Model Performance
#
# ### Example
#
# Suppose we build a house-price prediction model.
#
#     Actual price     = 500
#     Predicted price  = 450
#
# The error is:
#
#     500 - 450 = 50
#
# We do this for many houses and then calculate MAE or MSE.
#
# These values tell us **how much error the model is making**.
#
# ---
#
# ## 11. Comparing Two Models
#
# MAE and MSE can also be used to compare different regression models.
#
# | Model | MAE | MSE |
# |---|---:|---:|
# | Model A | 20 | 500 |
# | Model B | 12 | 250 |
#
# Model B has lower MAE and MSE.
#
# Therefore, Model B generally has **better prediction performance on the same evaluation data**.
#
# ---
#
# ## 12. MAE and MSE in Python
#
# We can calculate MAE and MSE using `scikit-learn`:
#
#     from sklearn.metrics import mean_absolute_error, mean_squared_error
#
#     mae = mean_absolute_error(y_test, y_pred)
#     mse = mean_squared_error(y_test, y_pred)
#
#     print("MAE:", mae)
#     print("MSE:", mse)
#
# Here:
#
# - `y_test` → actual values
# - `y_pred` → predicted values
#
# ---
#
# ## 13. Easy Way to Remember
#
# ### Slope
#
# > How much does `y` change when `x` changes?
#
# ### Best Fit Line
#
# > The line that fits the data as well as possible.
#
# ### Error
#
# > How far is the prediction from the actual value?
#
# ### MAE
#
# > How wrong is the model on average?
#
# ### MSE
#
# > How much should large errors be penalized?
#
# ---
#
# ## Key Takeaways
#
# - **Slope (`m`)** tells how much `y` changes when `x` changes.
# - **Gradient** is another name for slope.
# - **Intercept (`b`)** is the value of `y` when `x = 0`.
# - `y = mx + b` is the equation of a straight line.
# - **Best Fit Line** is the line that represents the data as well as possible.
# - **Error** is the difference between actual and predicted values.
# - **Loss** measures how wrong the model's predictions are.
# - **MAE** is the average absolute error.
# - **MSE** is the average squared error.
# - MSE gives more importance to **large errors**.
# - MAE and MSE are commonly used to **evaluate regression models**.
# - Generally, **lower MAE or MSE means better predictions** when comparing models on the same dataset and target scale.

# %% [markdown]
# # Derivatives and Partial Derivatives
#
# ## Derivative
#
# A **derivative tells us how fast something is changing**.
#
# In simple words:
#
# > **Derivative = slope at a particular point**
#
# Example:
#
# $$
# y = x^2
# $$
#
# Derivative:
#
# $$
# \frac{dy}{dx} = 2x
# $$
#
# ---
#
# ## Partial Derivative
#
# A **partial derivative** is used when there are **multiple variables**.
#
# It tells us how **one variable affects the output while keeping the other variables constant**.
#
# Example:
#
# $$
# f(x,y) = x^2 + y^2
# $$
#
# Partial derivative with respect to `x`:
#
# $$
# \frac{\partial f}{\partial x} = 2x
# $$
#
# ---
#
# ## In Machine Learning
#
# Derivatives are used in **Gradient Descent** to find the direction that reduces the **loss/error**.
#
# ### Remember
#
# - **Derivative** → slope at a point
# - **Partial Derivative** → effect of one variable while others stay constant
# - **Gradient Descent** → uses derivatives to reduce loss

# %% [markdown]
# # Chain Rule
#
# The **Chain Rule** is used when one function is inside another function.
#
# In simple words:
#
# > **Chain Rule helps us find how the final output changes by going through each step.**
#
# ### Example
#
# $$
# y = (x^2 + 1)^3
# $$
#
# Using Chain Rule:
#
# $$
# \frac{dy}{dx} = 3(x^2+1)^2 \times 2x
# $$
#
# Therefore:
#
# $$
# \frac{dy}{dx} = 6x(x^2+1)^2
# $$
#
# ### Easy Way to Remember
#
# > **Outer derivative × Inner derivative**
#
# ### In Machine Learning
#
# The Chain Rule is important in **Gradient Descent and Backpropagation**.
#
# It helps us find how a change in a model parameter affects the final **loss/error**.

# %% [markdown]
# # Gradient Descent Theory
#
# ## What is Gradient Descent?
#
# **Gradient Descent** is an algorithm used to **reduce the loss/error of a machine learning model**.
#
# In simple words:
#
# > Gradient Descent finds the direction in which the loss decreases and updates the model step by step.
#
# ### Easy Example
#
# Imagine you are standing on a hill and want to reach the lowest point.
#
# - Hill → Loss function
# - Your position → Model parameters
# - Downhill direction → Gradient
# - Step size → Learning rate
# - Lowest point → Minimum loss
#
# ## How Gradient Descent Works
#
# 1. Start with some parameter values.
# 2. Calculate the loss.
# 3. Calculate the gradient.
# 4. Move in the direction that reduces the loss.
# 5. Repeat the process.
# 6. Stop when the loss becomes minimum or very small.
#
# ## Important Terms
#
# - **Loss** → tells how wrong the model is.
# - **Gradient** → tells which direction the loss increases.
# - **Learning Rate** → controls how big each step is.
# - **Parameters** → values such as weights and bias that the model updates.
#
# ## Learning Rate
#
# The **learning rate** controls how big a step Gradient Descent takes.
#
# - Too large → may jump over the minimum.
# - Too small → learning becomes very slow.
# - Suitable learning rate → reaches the minimum efficiently.
#
# ## In Simple Words
#
# > **Gradient Descent = Keep changing the model parameters in the direction that reduces the error.**
#
# ## Why is it Important?
#
# Gradient Descent is widely used in Machine Learning to **find better model parameters and minimize the loss**.
#
# It is especially important in:
#
# - Linear Regression
# - Logistic Regression
# - Neural Networks
# - Deep Learning
# - Backpropagation

# %% [markdown]
# # Gradient Descent: Python Implementation

# %% [markdown]
# ## Gradient Descent - Key Points
#
# ## Gradient Descent
#
# As a Data Scientist or AI Engineer, we usually use **ML libraries** instead of implementing Gradient Descent from scratch.
#
# But we should understand how it works because it is important for:
#
# - Understanding Machine Learning
# - Interviews
# - Understanding model training
#
# ## Learning Rate
#
# **Learning rate** controls how big a step the model takes while reducing the loss.
#
# - Too large → may skip the minimum
# - Too small → training becomes slow
# - Good learning rate → reaches the minimum efficiently
#
# ## Epochs
#
# An **epoch** means one complete pass through the training data.
#
# More epochs allow the model to update its parameters more times.
#
# ## Gradient Descent Parameters
#
# For Linear Regression:
#
# $$
# y = mx + b
# $$
#
# - `m` → slope / coefficient
# - `b` → intercept
# - Learning rate → controls the size of each update
# - Epochs → number of times the model updates
#
# ## Model Results
#
# `model.coef_` gives the **coefficient (slope)**.
#
# Example:
#
#     model.coef_
#     [0.05168176]
#
# `model.intercept_` gives the **intercept**.
#
# Example:
#
#     model.intercept_
#     18.0465
#
# So the learned equation is approximately:
#
# $$
# y = 0.05168x + 18.0465
# $$
#
# ## Final Result
#
# After many epochs, Gradient Descent finds values of `m` and `b` that give a **low cost/loss**.
#
# ### Remember
#
# > **Gradient Descent = Update `m` and `b` step by step to reduce the cost.**
#
# > **Learning rate = How big each step is.**
#
# > **Epochs = How many times we repeat the updates.**

# %%
import pandas as pd

# %%
import numpy as np

# %%
def gradient_descent(x,y,lr=0.01,epochs=3000):
    m,b=0.0 , 0.0

    for epoch in range(epochs):
        y_pred = m*x + b
        error =y-y_pred
        cost=np.mean(error**2)

        dm=-2*np.mean(x*error)
        db=-2*np.mean(error)

        b-=db*lr
        m-=dm*lr

        print(f"m={m} , b={b} , Epoch={epochs} cost={cost}")

if __name__ == "__main__":
    x=np.array([1,2,3,4,5])
    y=np.array([5,7,9,11,13])
    gradient_descent(x,y)

# %%
def gradient_descent(x, y, lr=0.1, epochs=3000):
    # Scale x and y using Min-Max Scaling
    x_min, x_max = x.min(), x.max()
    y_min, y_max = y.min(), y.max()

    x_scaled = (x - x_min) / (x_max - x_min)
    y_scaled = (y - y_min) / (y_max - y_min)

    # Initialize parameters
    b = 0.0  # Intercept
    m = 0.0  # Slope
    n = len(y_scaled)  # Number of data points

    # Perform gradient descent
    for epoch in range(epochs):
        y_pred = b + m * x_scaled  # Predicted y values
        error = y_scaled - y_pred  # Error in prediction
        cost = np.mean(error ** 2)   # Mean squared error

        # Calculate gradients
        db = -2 * np.mean(error)  # Derivative w.r.t. intercept b
        dm = -2 * np.mean(error * x_scaled)  # Derivative w.r.t. slope m

        # Update parameters
        b -= lr * db
        m -= lr * dm

        # Optional: Print cost every 100 iterations to monitor progress
        if epoch % 100 == 0:
            print(f"Epoch {epoch}: Cost = {cost}, b = {b}, m = {m}")

    # Scale back the coefficients to original scale
    b_original = b * (y_max - y_min) + y_min - m * (y_max - y_min) * x_min / (x_max - x_min)
    m_original = m * (y_max - y_min) / (x_max - x_min)

    return b_original, m_original


if __name__ == "__main__":
    df = pd.read_csv(r"..\Datasets\home_prices.csv")

    x = df["area_sqr_ft"].to_numpy()
    y = df["price_lakhs"].to_numpy()

    b, m = gradient_descent(x, y)

    print(f"Final Results: m={m}, b={b}")
# Out:
# Epoch 0: Cost = 0.2564831062314152, b = 0.08397689768976899, m = 0.05399231750098086
# Epoch 100: Cost = 0.045238527469297275, b = 0.16916604992569337, m = 0.5099109453609146
# Epoch 200: Cost = 0.044639043137800115, b = 0.13609990777687922, m = 0.5708534773777333
# Epoch 300: Cost = 0.04461681897553835, b = 0.1297333115176334, m = 0.5825874285178556
# Epoch 400: Cost = 0.044615995078461666, b = 0.1285074791315702, m = 0.5848466981084404
# Epoch 500: Cost = 0.044615964534840506, b = 0.12827145583473568, m = 0.585281700693843
# Epoch 600: Cost = 0.04461596340252335, b = 0.12822601161472477, m = 0.5853654566343008
# Epoch 700: Cost = 0.044615963360545935, b = 0.12821726172791226, m = 0.585381583107562
# Epoch 800: Cost = 0.04461596335898974, b = 0.12821557701379, m = 0.5853846881188415
# Epoch 900: Cost = 0.04461596335893206, b = 0.12821525263683137, m = 0.5853852859615863
# Epoch 1000: Cost = 0.044615963358929915, b = 0.128215190180887, m = 0.5853854010709744
# ...

# %% [markdown]
# ## Final Result
#
# The **Machine Learning Linear Regression model** and the **Gradient Descent implementation** give the same final values:
#
# $$
# m = 0.05168175548989362
# $$
#
# $$
# b = 18.046501102723752
# $$
#
# This shows that both approaches found the **same slope (`m`) and intercept (`b`)**.
#
# > **So, the final output is the same for Machine Learning and Gradient Descent.**
