# %%
import pandas as pd

# %%
Data=pd.Series([1,2,3,-4])
print(Data)
# Out:
# 0    1
# 1    2
# 2    3
# 3   -4
# dtype: int64

# %%
Data.head(1)
# Out:
# 0    1
# dtype: int64

# %%
Data.tail(1)
# Out:
# 3   -4
# dtype: int64

# %%
Data.sample(2)
# Out:
# 3   -4
# 1    2
# dtype: int64
