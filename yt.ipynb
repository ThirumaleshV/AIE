# %% [markdown]
# #### is and isnot

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print(a is b)
print(a is c)
print(a == c)

print(a is not c)
# Out:
# True
# False
# True
# True

# %% [markdown]
# ##### Smaller integers between -5 to 256 is true,
# ##### Larger integers than -5 to 256 is false

# %%
x=10
y=10  
print(x is y)
# Out:
# True

# %%
a=300
b=300
print(a is b)
# Out:
# False
